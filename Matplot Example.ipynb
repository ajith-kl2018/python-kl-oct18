# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4,5])
plt.ylabel('Some Significant Numbers')
plt.show()

# %% [markdown]
# # Integrated with Numpy

# %%
t = np.arange(0.,5.,0.2)

# %%
plt.plot(t,t,'r--',t,t**2,'gs',t,t**3,'y^')
plt.axis([0,6,0,150]) #x and y axis range
plt.show()

# %%
mu, sigma = 100, 15 
x = mu + sigma * np.random.randn(10000) 

# the histogram of the data 
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)

plt.xlabel('Smarts') 
plt.ylabel('Probability')
plt.title('Histogram of IQ') 
plt.text(60, .025, r'$\mu=100,\ \sigma=15$') #TeX equations 
plt.axis([40, 160, 0, 0.03]) 
plt.grid(True) 
plt.show()
# Out:
# /anaconda3/envs/pyoct18/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6510: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
